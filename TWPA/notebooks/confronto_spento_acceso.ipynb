# %%
from utils import *
# %load_ext autoreload
# %autoreload 2
# Out:
# C:\Users\oper\Desktop\labparamp\QTLab2122\TWPA\Classes
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %matplotlib notebook

# %%
field_fox = vna('192.168.3.3')
field_fox.query('*IDN?')
# Out:
# 'Keysight Technologies,N9916A,MY53104702,A.08.01\n'

# %%
f,d_on = field_fox.print_data()

# %%
my_plot(f, d_on)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
f, d_on2 = field_fox.print_data()

# %%
f, d_off = field_fox.print_data()

# %%
f.size
# Out:
# 201

# %%
np.where(f>=3.3e9)[0][0]
# Out:
# 22

# %%
np.where(f>=8.2e9)[0][0]
# Out:
# 104

# %%
plt.xlim(3.3,8.2)
plt.plot(f/1e9,d_on - d_off)
fit_line = np.ones(f.size) * np.mean((d_on-d_off)[22:104])
plt.plot(f/1e9, fit_line)
print(np.mean((d_on-d_off)[22:104]))
print(np.std((d_on-d_off)[22:104]))
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# 4.244724397085366
# 2.043288829717314

# %%
plt.xlim(3.3,8.2)
plt.plot(f/1e9,d_on2 - d_off)
fit_line = np.ones(f.size) * np.mean((d_on2-d_off)[22:104])
plt.plot(f/1e9, fit_line)
print(np.mean((d_on2-d_off)[22:104]))
print(np.std((d_on2-d_off)[22:104]))
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# 4.074307885219512
# 1.8152757436646578

# %%
filename = 'confronto_spento_acceso.hdf5'
storage_hdf5(filename, f, 'freq')
storage_hdf5(filename, d_off, 'spento')
storage_hdf5(filename, d_on, 'max_at_0.338V')
storage_hdf5(filename, d_on2, 'max_at_0.312V')
