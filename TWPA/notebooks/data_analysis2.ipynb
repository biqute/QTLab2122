# %%
import numpy as np
import time
import os
import math
import h5py
from matplotlib import colors as mcolors
from utils import *

# %%
# %matplotlib notebook

# %%
mappa=get_hdf5('scan.hdf5', 'mappa')
freq=get_hdf5('scan.hdf5', 'freq')
spectra=get_hdf5('scan.hdf5', 'spectra')

# %%
i, j = np.where(mappa==mappa.max())

# %%
print(i,j)
# Out:
# [3558] [13]

# %%
plt.plot(freq/1e9, np.squeeze(spectra[i,:,j]))
plt.xlabel('Frequency (GHz)')
plt.ylabel('S21 (dB)')
plt.savefig('scan_fotobrutta.png')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
F=get_hdf5('gain_at5GHz_vs_pump _frequency3.hdf5', 'pump_freq')
maxima=get_hdf5('gain_at5GHz_vs_pump _frequency3.hdf5', 'maxima')

# %%
plt.plot(F/1e9, maxima)
plt.xlabel('Frequency (GHz)')
plt.ylabel('Power level (dBm)')
plt.savefig('freq_5GHz.png')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
P=get_hdf5('gain@5GHz_vs_pump _powero.hdf5', 'pump_ampl')
maxima=get_hdf5('gain@5GHz_vs_pump _powero.hdf5', 'maxima')

# %%
plt.plot(P, maxima)
plt.xlabel('Pump Power (dBm)')
plt.ylabel('Power level (dBm)')
#plt.savefig('pump_5GHz.png')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# Text(0, 0.5, 'Power level (dBm)')

# %%
P[np.where(maxima==maxima.max())]
# Out:
# array([-18.33333333, -18.07692308, -17.82051282, -17.56410256])

# %%
#pump5G=get_hdf5('scan_picco_at_5GHz.hdf5', 'pump_pow')
freq5G=get_hdf5('scan_picco_at_5GHz.hdf5', 'pump_freq')
bias5G=get_hdf5('scan_picco_at_5GHz.hdf5', 'bias_voltage')
maxima=get_hdf5('scan_completa_at_5_GHz1.hdf5', 'maxima')

maxima.shape
# Out:
# (2500, 21, 10)

# %%
print(freq5G.shape)
print(pump5G.shape)
print(bias5G.shape)
# Out:
# (2500,)
# (5,)
# (21,)

# %%
pump5G=np.array([-18.5,-18.4, -18.3,-18.2, -18.1, -18, -17.9, -17.8 ,-17.7, -17.6])

# %%
A, B, C = indexes_of_max(maxima)
print(A)
print(B)
print(C)

print(freq5G[A[0]])
print(bias5G[B[0]])
print(pump5G[C[0]])
# Out:
# [839 840 841 842]
# [19 19 19 19]
# [1 1 1 1]
# 17917800000.0
# 0.338
# -18.4

# %%
pump5G.shape
# Out:
# (10,)

# %%
plt.plot(pump5G, maxima[839,19,:], '-r')
plt.xlabel('Pump Power (dBm)')
plt.ylabel('Power level (dBm)')
plt.savefig('pump_level_5G.png')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
 maxima[839,19,:]
bias5G.shape
# Out:
# (21,)

# %%
plt.plot(freq5G/1e9, maxima[:,19,1])
plt.xlabel('Pump Frequency (GHz)')
plt.ylabel('Power level (dBm)')
plt.savefig('freq_level_5G.png')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
plt.plot(bias5G*2.24, maxima[830,:,1], '-g')
plt.xlabel('Bias Current (mA)')
plt.ylabel('Power level (dBm)')
plt.savefig('bias_level_5G.png')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
